# %%
# %matplotlib inline
from Rb_test import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/1min/RB.SHF.1MIN_PLUS.csv')
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束，共用时：72.9227919579 seconds.

# %%
ploter(Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pf
# Out:
#            0                 1
# 0       开始时间   2011/10/31 9:35
# 1       结束时间  2016/10/28 14:45
# 2      年化收益率           6.9592%
# 3     平均每年收益             6.88%
# 4      年化波动率             5.46%
# 5        夏普率     1.25934099326
# 6       最大回撤             4.37%
# 7     最大回撤周期               235
# 8   Calmar比率     1.59384443264
# 9       交易次数               437
# 10       盈亏比     1.45141405468
# 11        胜率            54.46%

# %%
# %matplotlib inline
from Rb_test import *
from perforanalyze import *
IF_Accountsummny = runstrategy('../../ts_data/1min/IF00.1MIN_PLUS.csv')
IF_pf,IF_Pnl = stratanalyz(IF_Accountsummny)
# Out:
# 回测结束，共用时：61.8637359142 seconds.

# %%
ploter(IF_Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
IF_pf
# Out:
#            0                 1
# 0       开始时间   2011/10/31 9:35
# 1       结束时间  2016/10/28 14:45
# 2      年化收益率           7.2143%
# 3     平均每年收益             9.32%
# 4      年化波动率            21.70%
# 5        夏普率    0.429542156247
# 6       最大回撤            28.86%
# 7     最大回撤周期               393
# 8   Calmar比率    0.249979029588
# 9       交易次数               672
# 10       盈亏比     1.06173581297
# 11        胜率            46.58%
