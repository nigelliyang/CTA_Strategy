# %%
symlist = ["AU00.SHF","CF00.CZC", "CU00.SHF", "J00.DCE",
           "L00.DCE","P00.DCE", "RB00.SHF","RU00.SHF",
           "SR00.CZC","M00.DCE"]

# %%
# %matplotlib inline
from bollinger_pairs import *
from perforanalyze import *

ret, price = runstrategy(30,'../winddata/SR00.CZC.csv','../winddata/P00.DCE.csv')
pf = stratanalyz(ret)

# %%
ploter(price, ret)

# %%
pf
# Out:
#                Performance
# APR               10.6045%
# trades                 750
# maxDD               23.31%
# Winrate             53.87%
# Ann_Volatility      17.95%
# Sharpe_ratio      0.652515
# Avg_Ann_Ret         11.71%
# maxDDD                 229
# payoff             1.03097
