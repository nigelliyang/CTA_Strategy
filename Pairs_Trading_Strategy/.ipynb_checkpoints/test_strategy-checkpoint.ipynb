# %%
symlist = ["AU00.SHF","CF00.CZC", "CU00.SHF", "J00.DCE",
           "L00.DCE","P00.DCE", "RB00.SHF","RU00.SHF",
           "SR00.CZC","M00.DCE"]

# %%
# %matplotlib inline
from bollinger_pairs import *
from perforanalyze import *

ret, price = runstrategy(20,'../winddata/SR00.CZC.csv','../winddata/P00.DCE.csv')
pf = stratanalyz(ret)

# %%
ploter(price, ret)

# %%
pf
# Out:
#                Performance
# APR                6.6576%
# trades                 699
# maxDD               23.62%
# Winrate             53.65%
# Ann_Volatility      16.41%
# Sharpe_ratio      0.475107
# Avg_Ann_Ret          7.80%
# maxDDD                 241
# payoff            0.994707
