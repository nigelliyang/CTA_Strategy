# %%
# %matplotlib inline
from ts_backtest import *
from perforanalyze import *

ret,price = backtest(250, 25, '../winddata/J00.DCE.csv')

pf = stratanalyz(ret)

# %%
pf
# Out:
#                Performance
# APR                9.6810%
# trades                 369
# maxDD               46.02%
# Winrate             19.13%
# Ann_Volatility      28.44%
# Sharpe_ratio      0.468017
# Avg_Ann_Ret         13.31%
# maxDDD                 224
# payoff             1.10082

# %%
ploter(price, ret)
