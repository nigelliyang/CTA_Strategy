# %% [markdown]
# #### 先回测的是可以在夜盘开仓的策略

# %%
# %matplotlib inline
from bog_nightopen_test import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/J00.DCE.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)

# %%
# %matplotlib inline
from bog_nightopen_test import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/day/L.DCE.DAY.csv',0.9,0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %matplotlib inline
from bog_nightopen_test import *
from perforanalyze import *
all_pf = pd.DataFrame()
for i in 0.01*np.arange(1,100):
    Accountsummny = runstrategy('../../ts_data/day/P.DCE.DAY.csv',i ,0.1 ,60)
    pf,Pnl = stratanalyz(Accountsummny)
    all_pf = pd.concat([all_pf, pf[1]],axis=1)
all_pf.columns = 0.01*np.arange(1,100)
# Out:
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束
# 回测结束

# %%
all_pf.T.sort(columns=3)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#               0           1     2          3        4      5   \
# 0.44  2011/10/31  2016/10/28  1214  -10.1392%  -10.42%  7.33%
# 0.23  2011/10/31  2016/10/28  1214  -10.1785%  -10.45%  7.53%
# 0.24  2011/10/31  2016/10/28  1214  -10.3126%  -10.60%  7.53%
# 0.26  2011/10/31  2016/10/28  1214  -10.3205%  -10.61%  7.54%
# 0.25  2011/10/31  2016/10/28  1214  -10.5193%  -10.82%  7.59%
# 0.27  2011/10/31  2016/10/28  1214  -10.7519%  -11.08%  7.60%
# 0.28  2011/10/31  2016/10/28  1214  -10.8569%  -11.20%  7.63%
# 0.43  2011/10/31  2016/10/28  1214  -11.0113%  -11.38%  7.52%
# 0.30  2011/10/31  2016/10/28  1214  -11.1011%  -11.47%  7.67%
# 0.31  2011/10/31  2016/10/28  1214  -11.1011%  -11.47%  7.67%
# 0.29  2011/10/31  2016/10/28  1214  -11.1011%  -11.47%  7.67%
# 0.32  2011/10/31  2016/10/28  1214  -11.2736%  -11.66%  7.70%
# 0.34  2011/10/31  2016/10/28  1214  -11.3314%  -11.73%  7.63%
# 0.42  2011/10/31  2016/10/28  1214  -11.3728%  -11.78%  7.59%
# 0.33  2011/10/31  2016/10/28  1214  -11.4225%  -11.83%  7.70%
# 0.39  2011/10/31  2016/10/28  1214  -11.4973%  -11.92%  7.62%
# 0.40  2011/10/31  2016/10/28  1214  -11.4973%  -11.92%  7.62%
# 0.41  2011/10/31  2016/10/28  1214  -11.4973%  -11.92%  7.62%
# 0.38  2011/10/31  2016/10/28  1214  -11.4973%  -11.92%  7.62%
# 0.35  2011/10/31  2016/10/28  1214  -11.5223%  -11.94%  7.65%
# 0.36  2011/10/31  2016/10/28  1214  -11.6392%  -12.07%  7.69%
# 0.37  2011/10/31  2016/10/28  1214  -11.8665%  -12.33%  7.73%
# 0.01  2011/10/31  2016/10/28  1214   -6.9328%   -6.88%  7.75%
# 0.02  2011/10/31  2016/10/28  1214   -6.9328%   -6.88%  7.75%

# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2822b7ddeef9> in <module>()
#       1 from bog_dayopen_test import *
# ----> 2 Accountsummny = runstrategy('../../ts_data/day/J.DCE.DAY.csv',0.1,60)
#       3 pf,Pnl = stratanalyz(Accountsummny)
#
# /Users/zhaoyong/my_project/GF_Work/CTA_Strategy/bog_day_strategy/bog_dayopen_test.py in runstrategy(filename, m, n)
#      60             #print bars.index[t], 'sell'
#      61             Pos[t] = -1
# ---> 62             Openorder[t] = {'Type': -1,'Openpos':bars['dayopen'].values[t],'Vol':1, 'Time': bars.index[t]}
#      63             Closeorder[t] = {'Type': 1,'Closepos':bars['close'].values[t],'Vol':1, 'Time': bars.index[t]}
#      64             Account[t] = (bars['close'].values[t]-bars['dayopen'].values[t])*Pos[t]
#
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'dayopen'

# %%
ploter(Accountsummny)

# %%
pf
# Out:
#            0               1
# 0       开始时间      2012/10/18
# 1       结束时间      2016/10/26
# 2       回测周期             977
# 3      年化收益率         0.2769%
# 4     平均每年收益           0.28%
# 5      年化波动率           0.42%
# 6        夏普率  0.663223508302
# 7       最大回撤           1.23%
# 8     最大回撤周期             492
# 9   Calmar比率  0.225822393114
# 10      交易次数             289
# 11       盈亏比    1.2593840231
# 12        胜率          47.75%

# %% [markdown]
# 用夜间开盘价比较信号

# %%
# %matplotlib inline
from bog_daytest import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/M00.DCE.addopen.csv',0.01,20)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)

# %%
pf
# Out:
#            0              1
# 0       开始时间     2012/10/18
# 1       结束时间     2016/10/26
# 2       回测周期            977
# 3      年化收益率        0.9071%
# 4     平均每年收益          0.90%
# 5      年化波动率          0.38%
# 6        夏普率  2.35988879799
# 7       最大回撤          0.24%
# 8     最大回撤周期            135
# 9   Calmar比率  3.71209324148
# 10      交易次数            332
# 11       盈亏比  2.26797153025
# 12        胜率         55.72%

# %%
# %matplotlib inline
from bog_daytest_2con import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/J00.DCE.addopen.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pf
# Out:
#            0              1
# 0       开始时间     2012/10/18
# 1       结束时间     2016/10/26
# 2       回测周期            977
# 3      年化收益率       13.4441%
# 4     平均每年收益         13.14%
# 5      年化波动率         10.32%
# 6        夏普率  1.27359374568
# 7       最大回撤          9.20%
# 8     最大回撤周期            210
# 9   Calmar比率  1.46058016693
# 10      交易次数            192
# 11       盈亏比  1.91920731707
# 12        胜率         40.10%
