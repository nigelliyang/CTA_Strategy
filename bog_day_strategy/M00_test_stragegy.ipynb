# %% [markdown]
# #### 先回测的是可以在夜盘开仓的策略
# 计算标准差的时间窗口60天更优

# %%
# %matplotlib inline
from bog_nightopen_test import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/M00.DCE.addopen.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %% [markdown]
# ### 在夜盘开后，改变信号

# %%
# %matplotlib inline
from bog_f2015 import *
from perforanalyze import *
Accountsummny = runstrategy('../../ts_data/M00.DCE.addopen.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pf
# Out:
#            0               1
# 0       开始时间        2015/2/2
# 1       结束时间      2016/10/26
# 2       回测周期             415
# 3      年化收益率        10.6505%
# 4     平均每年收益          11.15%
# 5      年化波动率          14.31%
# 6        夏普率  0.779063942709
# 7       最大回撤          10.38%
# 8     最大回撤周期             107
# 9   Calmar比率   1.02601028685
# 10      交易次数              99
# 11       盈亏比   1.32564102564
# 12        胜率          53.54%

# %%
Accountsummny = runstrategy('../../ts_data/J00.DCE.addopen.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)

# %% [markdown]
# ### 然后是只能在白天开盘的策略

# %%
pf
# Out:
#            0              1
# 0       开始时间       2015/2/2
# 1       结束时间     2016/10/26
# 2       回测周期            415
# 3      年化收益率       37.9415%
# 4     平均每年收益         33.03%
# 5      年化波动率         13.04%
# 6        夏普率  2.53259421353
# 7       最大回撤          6.97%
# 8     最大回撤周期             62
# 9   Calmar比率  5.44708958977
# 10      交易次数             91
# 11       盈亏比  2.92143808256
# 12        胜率         54.95%

# %%
from bog_dayopen_test import *
Accountsummny = runstrategy('../../ts_data/M00.DCE.addopen.csv',0.1,60)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)

# %%
pf
# Out:
#            0               1
# 0       开始时间      2012/10/18
# 1       结束时间      2016/10/26
# 2       回测周期             977
# 3      年化收益率         0.2769%
# 4     平均每年收益           0.28%
# 5      年化波动率           0.42%
# 6        夏普率  0.663223508302
# 7       最大回撤           1.23%
# 8     最大回撤周期             492
# 9   Calmar比率  0.225822393114
# 10      交易次数             289
# 11       盈亏比    1.2593840231
# 12        胜率          47.75%

# %%
'''
用来画入场点和出场点
opentrade = Accountsummny['Openorder'][Accountsummny['Openorder'].values != 0]
time_longs = [datetime.strptime(opentrade[i]['Time'], 
                          '%Y/%m/%d').date() for i in range(len(opentrade)) if opentrade.values[i]['Type'] == 1]
time_shorts = [datetime.strptime(opentrade[i]['Time'], 
                          '%Y/%m/%d').date() for i in range(len(opentrade)) if opentrade.values[i]['Type'] == -1]
longs = [opentrade[i]['Openpos'] for i in range(len(opentrade)) if opentrade.values[i]['Type'] == 1]
shorts = [opentrade[i]['Openpos'] for i in range(len(opentrade)) if opentrade.values[i]['Type'] == -1]
'''
