# %%
# %matplotlib inline
from BacktestDemo import *
from perforanalyze import *
initstrategy('../../ts_data/day/RB.SHF.DAY.csv')
Accountsummny = runstrategy(m=5,n=20)
pf,Pnl = stratanalyz(Accountsummny)
# Out:
# 回测结束

# %%
ploter(Accountsummny)
# Out:
# /Users/zhaoyong/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pf
# Out:
#            0              1
# 0       开始时间     2011/10/31
# 1       结束时间     2016/10/28
# 2       回测周期           1214
# 3      年化收益率       14.4037%
# 4     平均每年收益         13.90%
# 5      年化波动率          9.38%
# 6        夏普率   1.4811833252
# 7       最大回撤          9.85%
# 8     最大回撤周期            268
# 9   Calmar比率  1.46162080352
# 10      交易次数             54
# 11       盈亏比   3.3101965602
# 12        胜率         50.00%

# %%
# %matplotlib inline
from BacktestDemo import *
from perforanalyze import *
#Accountsummny = runstrategy('../winddata/CU00.SHF.csv',5,10)
#pf,Pnl = stratanalyz(Accountsummny)

all_pf = pd.DataFrame()
for sym in symlist:
    Accountsummny = runstrategy('../winddata/'+sym+'.csv',5,10)
    pf,Pnl = stratanalyz(Accountsummny)
    all_pf = pd.concat([all_pf, pf],axis=1)
all_pf.columns = symlist
# Out:
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束

# %%
all_pf
# Out:
#                 AU00.SHF  CF00.CZC CU00.SHF   J00.DCE    L00.DCE    P00.DCE  \
# Ann_Ann_Ret        5.09%    11.88%    7.31%     7.06%     -2.28%    -18.04%
# APR              4.4804%  11.7271%  6.9262%   2.4790%   -5.2216%  -19.4426%
# trades                57        66       67        53         63         61
# maxDD             13.58%    17.07%   12.28%    47.64%     35.27%     57.65%
# Winrate           40.35%    45.45%   50.75%    35.85%     46.03%     19.67%
# Ann_Volatility    11.90%    12.44%   11.09%    30.30%     24.76%     26.75%
# Sharpe_ratio    0.427611  0.954915  0.65912  0.232929 -0.0920178   -0.67425
# maxDDD               273       465      245       587        548        953
# payoff           1.37999   2.31935  1.67218   1.08271   0.801032    0.46641
#
#                 RB00.SHF RU00.SHF   SR00.CZC   M00.DCE
# Ann_Ann_Ret       13.78%   10.30%    -13.08%    13.43%
# APR             12.1888%  9.3889%  -13.9485%  13.1993%
# trades                59       63         79        58
# maxDD             37.94%   27.85%     56.60%    18.62%
# Winrate           50.85%   38.10%     29.11%    44.83%
# Ann_Volatility    21.30%   16.28%     19.54%    14.35%
# Sharpe_ratio    0.646701  0.63272  -0.669578  0.936259
# maxDDD               604      570        953       324
# payoff           1.70584  1.47247    0.55435   2.26479

# %%
ploter(Accountsummny)
