# %%
symlist = ["AU00.SHF","CF00.CZC", "CU00.SHF", "J00.DCE",
           "L00.DCE","P00.DCE", "RB00.SHF","RU00.SHF",
           "SR00.CZC","M00.DCE"]

# %%
# %matplotlib inline
from BacktestDemo import *
from perforanalyze import *
#Accountsummny = runstrategy('../winddata/CU00.SHF.csv',5,10)
#pf,Pnl = stratanalyz(Accountsummny)

all_pf = pd.DataFrame()
for sym in symlist:
    Accountsummny = runstrategy('../winddata/'+sym+'.csv',5,10)
    pf,Pnl = stratanalyz(Accountsummny)
    all_pf = pd.concat([all_pf, pf],axis=1)
all_pf.columns = symlist
# Out:
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束
# 加载数据完成
# 开始回测
# 回测结束

# %%
all_pf
# Out:
#                 AU00.SHF  CF00.CZC  CU00.SHF    J00.DCE   L00.DCE   P00.DCE  \
# Ann_Ann_Ret        0.02%     2.59%     4.43%      0.04%    -0.51%    -1.15%
# APR              0.0172%   2.5877%   4.2849%    0.0368%  -0.5451%  -1.1496%
# trades                57        66        67         53        63        61
# maxDD              0.05%     4.08%     7.57%      0.79%     4.78%     4.48%
# Winrate           40.35%    45.45%    50.75%     35.85%    46.03%    19.67%
# Ann_Volatility     0.05%     2.78%     6.84%      0.39%     2.75%     1.38%
# Sharpe_ratio    0.364046  0.933224  0.647314  0.0963032 -0.184885 -0.829565
# maxDDD               273       465       245        587       548       953
# payoff           1.37999   2.31935   1.67218    1.08271  0.801032   0.46641
#
#                 RB00.SHF RU00.SHF  SR00.CZC   M00.DCE
# Ann_Ann_Ret        0.52%    2.47%    -0.65%     0.68%
# APR              0.5199%  2.4192%  -0.6556%   0.6803%
# trades                59       63        79        58
# maxDD              1.39%    7.64%     3.53%     0.93%
# Winrate           50.85%   38.10%    29.11%    44.83%
# Ann_Volatility     0.71%    4.05%     0.92%     0.75%
# Sharpe_ratio    0.732908  0.61036 -0.707048  0.912327
# maxDDD               604      570       953       324
# payoff           1.70584  1.47247   0.55435   2.26479

# %%
ploter(Accountsummny)
